# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# pip install scikit-learn

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd

# Otros objetivos
# -----------------------------------------------------------------------
import math

# Gráficos
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")
from src.SupportPreProcesamiento import (
    exploracion_dataframe,
    separarar_df,
    plot_numericas,
    plot_categoricas,
    relacion_vr_categoricas,
    relacion_vr_numericas,
    matriz_correlacion,
    detectar_outliers,
    diferencia_tras_rellenar_nulos
)

pd.set_option('display.float_format', '{:.2f}'.format)


# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../../datos/06_Modelo6/01_autorenew.csv")

# %%
df.head()
# Out:
#            dateCrawled                            name   seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  private     offer
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  private     offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  private     offer
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  private     offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  private     offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerCV  model  \
# 0    480   test         NaN                1993   manually     0.00   golf
# 1  18300   test       coupe                2011   manually   187.00    NaN
# 2   9800   test         suv                2004  automatic   161.00  grand
# 3   1500   test   small car                2001   manually    74.00   golf
# 4   3600   test   small car                2008   manually    68.00  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   petrol  volkswagen               NaN
# 1     125000                    5   diesel        audi               yes
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   petrol  volkswagen                no
# 4      90000                    7   diesel       skoda                no
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %% [markdown]
# # EDA
# Vamos a realizar lo siguiente mediante las funciones previamente definidas:
# - explorar la info del Dataframe
# - visualizar las numéricas con un histplot
# - visualizar las categoricas con un countplot
# - visualizar los outliers con un boxplot
# - visualizar correlacion con heatmap
# - visualizar categoricas vs variable respuesta(barplot)
# - visualizar numericas vs variable respuesta con un (scatterplot)

# %% [markdown]
# ### Explorar la info del Dataframe
# Vamos a ver primero que datos tenemos y con que vamos a trabajar vamos a usar la funcion explorar DataFrame, usando como columna control

# %%
exploracion_dataframe(df,"price",estadisticos=False)
# Out:
# El número de datos es 371528 y el de columnas es 20
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 4
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                    %_nulos
# vehicleType          36.00
# gearbox               5.44
# model                 5.51
# fuelType              8.99
# notRepairedDamage    19.40
#  .....................
#
# Los tipos de las columnas son:
#                     tipo_dato
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerCV               float64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna DATECRAWLED tiene las siguientes valore únicos:
#                      count
# dateCrawled
# 2016-03-24 14:49:47      7
# 2016-03-26 22:57:31      6
# 2016-03-19 21:49:56      6
# 2016-03-22 10:42:10      5
# 2016-04-04 22:38:11      5
# La columna NAME tiene las siguientes valore únicos:
#                      count
# name
# Ford_Fiesta            657
# BMW_318i               627
# Opel_Corsa             622
# Volkswagen_Golf_1.4    603
# BMW_316i               523
# La columna SELLER tiene las siguientes valore únicos:
#              count
# seller
# private     371525
# commercial       3
# La columna OFFERTYPE tiene las siguientes valore únicos:
#             count
# offerType
# offer      371516
# request        12
# La columna ABTEST tiene las siguientes valore únicos:
#           count
# abtest
# test     192585
# control  178943
# La columna VEHICLETYPE tiene las siguientes valore únicos:
#              count
# vehicleType
# small car    80023
# combi        67564
# bus          30201
# convertible  22898
# coupe        19015
# La columna GEARBOX tiene las siguientes valore únicos:
#             count
# gearbox
# manually   274214
# automatic   77105
# La columna MODEL tiene las siguientes valore únicos:
#         count
# model
# golf    30070
# andere  26400
# 3er     20567
# polo    13092
# corsa   12573
# La columna FUELTYPE tiene las siguientes valore únicos:
#            count
# fuelType
# petrol    223857
# diesel    107746
# lpg         5378
# cng          571
# hybrid       278
# La columna BRAND tiene las siguientes valore únicos:
#                count
# brand
# volkswagen     79640
# bmw            40274
# opel           40136
# mercedes_benz  35309
# audi           32873
# La columna NOTREPAIREDDAMAGE tiene las siguientes valore únicos:
#                     count
# notRepairedDamage
# no                 263182
# yes                 36286
# La columna DATECREATED tiene las siguientes valore únicos:
#                      count
# dateCreated
# 2016-04-03 00:00:00  14450
# 2016-04-04 00:00:00  14022
# 2016-03-20 00:00:00  13547
# 2016-03-12 00:00:00  13379
# 2016-03-21 00:00:00  13305
# La columna LASTSEEN tiene las siguientes valore únicos:
#                      count
# lastSeen
# 2016-04-06 13:45:54     17
# 2016-04-07 06:45:59     17
# 2016-04-07 08:16:54     16
# 2016-04-06 09:46:00     16
# 2016-04-06 04:17:20     16

# %% [markdown]
# # Nuevo Modelo 4 Gestion duplicados
# - Eliminamos los duplicados ahora

# %%
df.duplicated().value_counts()
# Out:
# False    371524
# True          4
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Revisar tipo de nulos que tenemos

# %%
df[["vehicleType","gearbox","model","fuelType","notRepairedDamage"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371524 entries, 0 to 371527
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   vehicleType        237761 non-null  object
#  1   gearbox            351315 non-null  object
#  2   model              351040 non-null  object
#  3   fuelType           338138 non-null  object
#  4   notRepairedDamage  299464 non-null  object
# dtypes: object(5)
# memory usage: 17.0+ MB

# %%
for col in df[["vehicleType","gearbox","model","fuelType","notRepairedDamage"]].columns:
    print("\n ..................... \n")
    print(f"{col}")
    display(df[col].unique())
# Out:
#  .....................
#
# vehicleType
# array([nan, 'coupe', 'suv', 'small car', 'convertible', 'bus', 'combi',
#        'other'], dtype=object)
#  .....................
#
# gearbox
# array(['manually', 'automatic', nan], dtype=object)
#  .....................
#
# model
# array(['golf', nan, 'grand', 'fabia', '3er', '2_reihe', 'andere', 'c_max',
#        '3_reihe', 'passat', 'navara', 'ka', 'polo', 'twingo', 'a_klasse',
#        'scirocco', '5er', 'meriva', 'arosa', 'c4', 'civic', 'transporter',
#        'punto', 'e_klasse', 'clio', 'kadett', 'kangoo', 'corsa', 'one',
#        'fortwo', '1er', 'b_klasse', 'signum', 'astra', 'a8', 'jetta',
#        'fiesta', 'c_klasse', 'micra', 'vito', 'sprinter', '156', 'escort',
#        'forester', 'xc_reihe', 'scenic', 'a4', 'a1', 'insignia', 'combo',
#        'focus', 'tt', 'a6', 'jazz', 'omega', 'slk', '7er', '80', '147',
#        'glk', '100', 'z_reihe', 'sportage', 'sorento', 'v40', 'ibiza',
#        'mustang', 'eos', 'touran', 'getz', 'a3', 'almera', 'megane',
#        'lupo', 'r19', 'zafira', 'caddy', 'mondeo', 'cordoba', 'colt',
#        'impreza', 'vectra', 'berlingo', 'm_klasse', 'tiguan', 'i_reihe',
#        'espace', 'sharan', '6_reihe', 'panda', 'up', 'seicento', 'ceed',
#        '5_reihe', 'yeti', 'octavia', 'mii', 'rx_reihe', '6er', 'modus',
#        'fox', 'matiz', 'beetle', 'c1', 'rio', 'touareg', 'logan',
#        'spider', 'cuore', 's_max', 'a2', 'x_reihe', 'a5', 'galaxy', 'c3',
#        'viano', 's_klasse', '1_reihe', 'avensis', 'sl', 'roomster', 'q5',
#        'kaefer', 'santa', 'cooper', 'leon', '4_reihe', '500', 'laguna',
#        'ptcruiser', 'clk', 'primera', 'exeo', '159', 'transit', 'juke',
#        'qashqai', 'carisma', 'accord', 'corolla', 'lanos', 'phaeton',
#        'boxster', 'verso', 'swift', 'rav', 'kuga', 'picanto', 'kalos',
#        'superb', 'stilo', 'alhambra', '911', 'mx_reihe', 'm_reihe',
#        'roadster', 'ypsilon', 'cayenne', 'galant', 'justy', '90',
#        'sirion', 'crossfire', 'agila', 'duster', 'cr_reihe', 'v50',
#        'discovery', 'c_reihe', 'v_klasse', 'yaris', 'c5', 'aygo', 'cc',
#        'carnival', 'fusion', 'bora', 'forfour', 'cl', 'tigra', '300c',
#        'q3', 'spark', 'v70', 'x_type', 'ducato', 's_type', 'x_trail',
#        'toledo', 'altea', 'voyager', 'calibra', 'bravo', 'range_rover',
#        'antara', 'tucson', 'q7', 'citigo', 'jimny', 'cx_reihe',
#        'wrangler', 'lybra', 'range_rover_sport', 'lancer', 'freelander',
#        'captiva', 'c2', 'range_rover_evoque', 'sandero', 'note', '900',
#        'defender', 'cherokee', 'clubman', 'samara', '601', 'legacy',
#        'pajero', 'auris', 'niva', 's60', 'nubira', 'vivaro', 'g_klasse',
#        'lodgy', '850', 'serie_2', 'charade', 'croma', 'outlander', 'gl',
#        'doblo', 'musa', 'amarok', 'move', '9000', 'v60', '145', 'aveo',
#        '200', 'b_max', 'delta', 'terios', 'rangerover', 'materia',
#        'kalina', 'elefantino', 'i3', 'kappa', 'serie_3', 'serie_1',
#        'discovery_sport'], dtype=object)
#  .....................
#
# fuelType
# array(['petrol', 'diesel', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electro'], dtype=object)
#  .....................
#
# notRepairedDamage
# array([nan, 'yes', 'no'], dtype=object)

# %% [markdown]
# # Conclusiones
# - Tenemos 4 Duplicados
# - Tenemos 5 Columnas con nulos:
#     - vehicleType: 36% nulos categórica ['nan','coupe', 'suv', 'small car', 'convertible', 'bus', 'combi',
#        'other']
#     - gearbox: 5,5% nulos, categórica ['manually', 'automatic', nan]
#     - model: 5,51% nulos, categórica (No la pongo que son muchos)
#     - fuelType: 8,98% nulos categórica ['petrol', 'diesel', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electro']
#     - notRepairedDamage 19,39% nulos categorica [nan, 'yes', 'no']

# %% [markdown]
# # Las gráficas tardan mucho, porque? veamos:

# %%
df.describe().T
# Out:
#                         count      mean        std     min       25%  \
# price               371524.00  17295.30 3587973.06    0.00   1150.00
# yearOfRegistration  371524.00   2004.58      92.87 1000.00   1999.00
# powerCV             371524.00    113.97     189.52    0.00     69.00
# kilometer           371524.00 125618.84   40112.14 5000.00 125000.00
# monthOfRegistration 371524.00      5.73       3.71    0.00      3.00
# nrOfPictures        371524.00      0.00       0.00    0.00      0.00
# postalCode          371524.00  50820.49   25799.09 1067.00  30459.00
#
#                           50%       75%           max
# price                 2950.00   7200.00 2147483647.00
# yearOfRegistration    2003.00   2008.00       9999.00
# powerCV                104.00    148.00      19726.00
# kilometer           150000.00 150000.00     150000.00
# monthOfRegistration      6.00      9.00         12.00
# nrOfPictures             0.00      0.00          0.00
# postalCode           49610.00  71546.00      99998.00

# %% [markdown]
# Si miramos el valor máximo, de las columnas, no tiene sentido ni para price, ni yearof, ni powerCV, ni postal code, pero sobre todo vamos a limpiar nuestro DF, number of pictures no nos interesa, si siempre es 0, no afectara
#
# Postal code nos puede interesar

# %% [markdown]
# Dropeamos nrOfPictures

# %%
df.drop(columns="nrOfPictures",inplace=True)
df.sample()
# Out:
#                 dateCrawled                                           name  \
# 168949  2016-03-11 21:50:33  XC_90_D5_SPORT_DYNAUDIO_7_SITZE_1.HAND_S_HEFT
#
#          seller offerType  price abtest vehicleType  yearOfRegistration  \
# 168949  private     offer  10000   test         suv                2008
#
#           gearbox  powerCV     model  kilometer  monthOfRegistration fuelType  \
# 168949  automatic   182.00  xc_reihe      90000                    1   diesel
#
#         brand notRepairedDamage          dateCreated  postalCode  \
# 168949  volvo                no  2016-03-11 00:00:00       10115
#
#                    lastSeen
# 168949  2016-03-11 21:50:33

# %% [markdown]
# ## No podemos meter nulos a la variable respuesta
# (Pero sí dropear cosas sin sentido...)
# ### Veamos ahora price

# %% [markdown]
# Vamos a elimar las filas cuyo precio sea menor a 500€ ya que, un vehículo no se va a vender por menos de 500€

# %%
cond = df["price"] < 500
df[cond].shape
# Out:
# (36062, 19)

# %%
cond = df["price"] < 500
df = df.drop(df[cond].index)
df.reset_index(inplace=True, drop= True)

# %% [markdown]
# También vamos a elimar las filas donde el precio sea más de 80000€ ya que, son precios desorbitados, y no son muchas filas, además si nos fijamos son vehículos que no valen eso...

# %%
cond = df["price"] > 80000 #NUEVO MODELO 6
df[cond].shape
# Out:
# (580, 19)

# %%
cond = df["price"] > 80000 #NUEVO MODELO 6
df = df.drop(df[cond].index)
df.reset_index(inplace=True, drop= True)

# %% [markdown]
# Ahora veamos los valores más elevados

# %%
df["price"].nlargest(40).unique()
# Out:
# array([80000, 79999, 79993, 79980, 79950, 79933, 79900, 79500, 79499,
#        79480, 79111, 79000, 78993, 78964, 78911, 78900, 78500])

# %% [markdown]
# ### YearofRegistration
# Con el año de registro es fácil, si es mayor de 2024, es nulo

# %%
cond = df["yearOfRegistration"] > 2024
df.loc[cond,"yearOfRegistration"] = np.nan

# %% [markdown]
# y claro, el coche se invento en 1950, si es menor de eso es NAN

# %%
cond = df["yearOfRegistration"] < 1950
df[cond].shape
# Out:
# (144, 19)

# %%
cond = df["yearOfRegistration"] < 1950 #Nuevo Modelo 6
df.loc[cond,"yearOfRegistration"] = np.nan

# %% [markdown]
# ### Month
# Verifiquemos que hay

# %%
df["monthOfRegistration"].unique()
# Out:
# array([ 5,  8,  6,  7, 10,  0, 12, 11,  2,  3,  1,  4,  9])

# %% [markdown]
# El mes no nos va a aportar nada de valor tampoco, no me lo voy a cargar, pero si que voy a no tenerlo en cuenta

# %% [markdown]
# ### PowerCV
# un coche no puede tener menos de 50 CV, ni más de 1200 CV, asi que todo lo que se salga de rango, lo dejamos en NAN

# %%
cond = df["powerCV"] > 1200
df[cond].shape
# Out:
# (217, 19)

# %%
cond = df["powerCV"] > 1200
df.loc[cond,"powerCV"] = np.nan

# %%
cond = df["powerCV"] < 50
df[cond].shape
# Out:
# (37075, 19)

# %%
cond = df["powerCV"] < 50
df.loc[cond,"powerCV"] = np.nan

# %% [markdown]
# # Postal code
# Considero que no la vamos a usar, ademas considero que es una variable categórica

# %%
df.describe().T
# Out:
#                         count      mean      std     min       25%       50%  \
# price               334882.00   6145.90  7422.14  500.00   1500.00   3500.00
# yearOfRegistration  334675.00   2003.79     7.33 1950.00   2000.00   2004.00
# powerCV             297590.00    128.89    61.23   50.00     89.00    114.00
# kilometer           334882.00 125276.10 39585.96 5000.00 100000.00 150000.00
# monthOfRegistration 334882.00      5.92     3.63    0.00      3.00      6.00
# postalCode          334882.00  51261.88 25715.59 1067.00  30952.00  50226.00
#
#                           75%       max
# price                 7900.00  80000.00
# yearOfRegistration    2008.00   2019.00
# powerCV                154.00   1186.00
# kilometer           150000.00 150000.00
# monthOfRegistration      9.00     12.00
# postalCode           72119.00  99998.00

# %%
df["kilometer"].isna().value_counts()
# Out:
# kilometer
# False    334882
# Name: count, dtype: int64

# %% [markdown]
# # ¿Con que columnas numéricas vamos a trabajar?
# - price
# - yearOfRegistration
# - powerCV
# - Kilometer, que por como es la volveremos categórica
#
# Considero que el resto de columnas no aportan valor

# %% [markdown]
# # Columnas categóricas
# Ahora vamos a ver con que columnas categóricas nos quedamos y como gestionamos sus nulos

# %%
df.select_dtypes(include="O").head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 1  2016-03-14 12:52:21                     Jeep_Grand_Cherokee_"Overland"
# 2  2016-03-17 16:54:04                                 GOLF_4_1_4__3TÜRER
# 3  2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 4  2016-04-04 17:36:23  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
#
#     seller offerType abtest vehicleType    gearbox  model fuelType  \
# 0  private     offer   test       coupe   manually    NaN   diesel
# 1  private     offer   test         suv  automatic  grand   diesel
# 2  private     offer   test   small car   manually   golf   petrol
# 3  private     offer   test   small car   manually  fabia   diesel
# 4  private     offer   test         NaN   manually    3er   petrol
#
#         brand notRepairedDamage          dateCreated             lastSeen
# 0        audi               yes  2016-03-24 00:00:00  2016-04-07 01:46:50
# 1        jeep               NaN  2016-03-14 00:00:00  2016-04-05 12:47:46
# 2  volkswagen                no  2016-03-17 00:00:00  2016-03-17 17:40:17
# 3       skoda                no  2016-03-31 00:00:00  2016-04-06 10:17:21
# 4         bmw               yes  2016-04-04 00:00:00  2016-04-06 19:17:07

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'abtest', 'vehicleType',
#        'gearbox', 'model', 'fuelType', 'brand', 'notRepairedDamage',
#        'dateCreated', 'lastSeen'],
#       dtype='object')

# %% [markdown]
# ### Columnas categóricas que tienen que ver con el precio:
# - offerType
# - vehicleType
# - gearbox
# - fuelType
# - brand
# - notRepairedDamage
# - seller
#
# De estás veamos si se pueden usar

# %%
df["vehicleType"].unique()
# Out:
# array(['coupe', 'suv', 'small car', nan, 'convertible', 'bus', 'combi',
#        'other'], dtype=object)

# %%
df["gearbox"].unique()
# Out:
# array(['manually', 'automatic', nan], dtype=object)

# %%
df["fuelType"].unique()
# Out:
# array(['diesel', 'petrol', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electro'], dtype=object)

# %%
df["brand"].unique()
# Out:
# array(['audi', 'jeep', 'volkswagen', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'citroen',
#        'honda', 'fiat', 'mini', 'smart', 'hyundai', 'seat', 'subaru',
#        'volvo', 'mitsubishi', 'alfa_romeo', 'kia', 'suzuki', 'lancia',
#        'porsche', 'toyota', 'chevrolet', 'sonstige_autos', 'dacia',
#        'daihatsu', 'chrysler', 'jaguar', 'daewoo', 'rover', 'saab',
#        'land_rover', 'trabant', 'lada'], dtype=object)

# %%
df["notRepairedDamage"].unique()
# Out:
# array(['yes', nan, 'no'], dtype=object)

# %%
df["seller"].unique()
# Out:
# array(['private', 'commercial'], dtype=object)

# %%
df["offerType"].unique()
# Out:
# array(['offer', 'request'], dtype=object)

# %% [markdown]
# Podemos usarlas, vamos a crear un nuevo Dataframe con las columnas que usaremos, numericas y categóricas

# %%
df_old = df.copy() # Para tenerlo por si acaso

# %%
df = df[["seller","offerType","brand","vehicleType","fuelType","gearbox","notRepairedDamage","kilometer","powerCV","price","yearOfRegistration"]]
df["kilometer"] = df["kilometer"].astype("O")
df["yearOfRegistration"] = df["yearOfRegistration"].astype("O")

# %% [markdown]
# # Nuevo en el Modelo 5
# Vamos a categorizar "brand" en:
# - gama_extinta: La marca ya no fabrica vehículos
# - gama_baja: Vehículos baratos
# - gama_media: Vehículos de gama media
# - gama_alta: Vehículos caros
# - gama_lujo: Los ultra luxury
# - unknown: Si no sabemos marca chao

# %%
df["brand"].unique()
# Out:
# array(['audi', 'jeep', 'volkswagen', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'citroen',
#        'honda', 'fiat', 'mini', 'smart', 'hyundai', 'seat', 'subaru',
#        'volvo', 'mitsubishi', 'alfa_romeo', 'kia', 'suzuki', 'lancia',
#        'porsche', 'toyota', 'chevrolet', 'sonstige_autos', 'dacia',
#        'daihatsu', 'chrysler', 'jaguar', 'daewoo', 'rover', 'saab',
#        'land_rover', 'trabant', 'lada'], dtype=object)

# %% [markdown]
# - gama_extinta = ['daewoo','rover','saab','trabant','lancia']
# - gama_baja = ['dacia','daihatsu','lada','smart','suzuki','fiat','renault','skoda','peugeot','opel','citroen','chevrolet','nissan']
# - gama_media = ['ford','seat','honda','hyundai','subaru','mitsubishi','kia','toyota','chrysler','mazda']
# - gama_alta = ['volkswagen','audi','jeep','bmw','mercedes_benz','alfa_romeo','volvo','land_rover','mini']
# - gama_lujo = ['porsche','jaguar']
# - unknown = ['sonstige_autos']

# %%
gama_extinta = ['daewoo','rover','saab','trabant','lancia']
gama_baja = ['dacia','daihatsu','lada','smart','suzuki','fiat','renault','skoda','peugeot','opel','citroen','chevrolet','nissan']
gama_media = ['ford','seat','honda','hyundai','subaru','mitsubishi','kia','toyota','chrysler','mazda']
gama_alta = ['volkswagen','audi','jeep','bmw','mercedes_benz','alfa_romeo','volvo','land_rover','mini']
gama_lujo = ['porsche','jaguar']
unknown = ['sonstige_autos']

# %%
df["gama"] = "unknown"
df.loc[df["brand"].isin(gama_extinta), "gama"] = "gama_extinta"
df.loc[df["brand"].isin(gama_baja), "gama"] = "gama_baja"
df.loc[df["brand"].isin(gama_media), "gama"] = "gama_media"
df.loc[df["brand"].isin(gama_alta), "gama"] = "gama_alta"
df.loc[df["brand"].isin(gama_lujo), "gama"] = "gama_lujo"
df.loc[df["brand"].isin(unknown), "gama"] = "unknown"

# %%
df["gama"].value_counts()
# Out:
# gama
# gama_alta       184729
# gama_baja        92175
# gama_media       50380
# unknown           3027
# gama_lujo         2499
# gama_extinta      2072
# Name: count, dtype: int64

# %% [markdown]
# # Dropeamos brand y nos quedamos con gama

# %%
df.drop(columns="brand",inplace=True)

# %% [markdown]
# Este es el Df con el que voy a trabajar ahora, vamos a visualizar los datos ahora que ya hemos corregido los valores numéricos y los hemos pasado a NAN si eran datos que no tenían ningún sentido

# %% [markdown]
# ### Visualizar las numéricas con un histplot

# %%
numericas, categoricas = separarar_df(df)
plot_numericas(numericas)

# %% [markdown]
# # Sobre la gráfica
# Así de primeras podemos decir que la gran mayoría de los coches se encuentran alrededor de los 90 y los 2000, que la potencia se encuentra entre los 100 y 200 CV mayoritariamente y que el precio tiene muchos outliers
# - En general hay bastantes outliers, pero son manejables

# %% [markdown]
# ### Visualizar las categoricas con un countplot

# %%
plot_categoricas(categoricas,grafica_size=(20,20))

# %% [markdown]
# # Sobre la gráfica
# - Mayoritariamente los seller son privados
# - Mayoritariamente son ventas, no subastas
# - El tipo de vehiculo más anunciado es small car
# - Los más anunciados son coches gasolina
# - La caja de cambios más anunciada es la manual
# - La gran mayoría de los coches no tienen daños
# - La mayoría de los coches tienen 150000 km
# - La gama_alta es la más anunciada

# %% [markdown]
# ### Visualizar los outliers con un boxplot

# %%
detectar_outliers(df)

# %% [markdown]
# # Sobre la gráfica
# - Tenemos bastantantes outliers en todas las gráficas
# - Hay que tener en cuenta que no todos los coches son iguales así que no tienen porque ser valores incorrectos (que lo pueden ser)
# - El más preocupante diría que es precio con outliers tan elevados, aunque aún queda corregir nulos

# %% [markdown]
# ### Visualizar correlacion con heatmap

# %% [markdown]
# Aquí vamos a realizar dos, una del df original y otra del df tal y como está ahora, para asegurarnos de que no hemos perdido nada importante

# %%
matriz_correlacion(df_old)

# %% [markdown]
# # Sobre la Gráfica
# - Mayores correlaciones:
#     - powerCV con price: 0.56
#     - kilometer con price: 0.44
#     - kilometer con yearofRegistration: 0.25 pero ahora es categórica,
#     - yearofregist con Price: 0.16 pero ahora es categórica
#     - powerCV con yearofRegistration: 0.15
#
#     La correlación es baja, pero estás son las más altas, realmente deberíamos añadir los kilómetros (aqui me vuelvo a corregir eso)

# %%
matriz_correlacion(df)

# %% [markdown]
# # Sobre la gráfica
# - Viendo la anterior, hemos hecho bien, nos hemos quedado con los valores más correlacionados entre sí

# %% [markdown]
# ### Visualizar categoricas vs variable respuesta(barplot)

# %%
relacion_vr_categoricas(df,"price",grafica_size=(25,20))

# %% [markdown]
# # Sobre la gráfica
# - El precio parece ser menor en promedio en las ventas de comercial, los privados sacan mças de promedio
# - Las subastas sacan de promedio más dinero
# - Los coupé y suvs son los más caros, small car el más barato.
# - Los vehículos electrícos, híbridos y diesel los más caros, gasolina, cng y lpg son más baratos.
# - Los automáticos son más caros que los manuales ( y menos divertidos).
# - Los vehículos con daños sin reparar son mucho más baratos
# - Los vehículos de 5000 km son más baratos que los de 10.000,20.000... revisar nulos
# - Precio y registrationPrice, habrá que revisar, pero podrían ser vehículos de colección
# - Gama_lujo es la más cara, le sigue unkown, el orden tiene sentido

# %% [markdown]
# ### Visualizar numericas vs variable respuesta con un (scatterplot)

# %%
relacion_vr_numericas(df,"price",grafica_size=(20,6))

# %% [markdown]
# # Sobre la gráfica
#
# - La mayoría de los coches tienen entre 0 y 400 CV de potencia
# - outliers con coches de 800 CV, deberían ser de lujo o superdeportivos
# - A partir de 800CV los vehículos son demasiado baratos es probable que sean valores incorrectos, los voy a nulificar?

# %%
cond = df["powerCV"] > 800
df[cond].shape
# Out:
# (62, 11)

# %% [markdown]
# Los voy a nulificar

# %%
cond = df["powerCV"] > 800
df[cond]["gama"].unique()
# Out:
# array(['gama_media', 'gama_baja', 'gama_alta', 'unknown'], dtype=object)

# %% [markdown]
# Son todo marcas que no han tenido esa potencia nunca (salvando mercedes y bmw)

# %%
condicion = df["powerCV"] > 800
c2 = df["gama"] != "gama_alta"
df.loc[condicion & c2,"powerCV"] = np.nan

# %% [markdown]
# Ahora que ya hemos reducido los outliers excesivos, podemos empezar a trabajar los nulos

# %% [markdown]
# 2. **Gestión de Valores Nulos:** Identifica las columnas que contienen valores nulos y aplica las técnicas adecuadas para manejarlos. Esto podría incluir la imputación de valores, eliminación de filas o columnas, o cualquier otra estrategia que consideres apropiada.
#
# Ahora vamos a rellenar nulos!

# %% [markdown]
# # Columnas categóricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334882 entries, 0 to 334881
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   seller              334882 non-null  object
#  1   offerType           334882 non-null  object
#  2   vehicleType         217599 non-null  object
#  3   fuelType            311165 non-null  object
#  4   gearbox             321238 non-null  object
#  5   notRepairedDamage   279458 non-null  object
#  6   kilometer           334882 non-null  object
#  7   powerCV             297552 non-null  float64
#  8   price               334882 non-null  int64
#  9   yearOfRegistration  334675 non-null  object
#  10  gama                334882 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 28.1+ MB

# %%
exploracion_dataframe(df,"price")
# Out:
# El número de datos es 334882 y el de columnas es 11
#
#  .....................
#
# Los duplicados que tenemos en el conjunto de datos son: 56559
#
#  .....................
#
# Los nulos que tenemos en el conjunto de datos son:
#                     %_nulos
# vehicleType           35.02
# fuelType               7.08
# gearbox                4.07
# notRepairedDamage     16.55
# powerCV               11.15
# yearOfRegistration     0.06
#  .....................
#
# Los tipos de las columnas son:
#                    tipo_dato
# seller                object
# offerType             object
# vehicleType           object
# fuelType              object
# gearbox               object
# notRepairedDamage     object
# kilometer             object
# powerCV              float64
# price                  int64
# yearOfRegistration    object
# gama                  object
#  .....................
#
# Los valores que tenemos para las columnas categóricas son:
# La columna SELLER tiene las siguientes valore únicos:
#              count
# seller
# private     334880
# commercial       2
# La columna OFFERTYPE tiene las siguientes valore únicos:
#             count
# offerType
# offer      334877
# request         5
# La columna VEHICLETYPE tiene las siguientes valore únicos:
#              count
# vehicleType
# small car    68470
# combi        63122
# bus          29250
# convertible  22065
# coupe        17457
# La columna FUELTYPE tiene las siguientes valore únicos:
#            count
# fuelType
# petrol    199997
# diesel    105047
# lpg         5101
# cng          538
# hybrid       266
# La columna GEARBOX tiene las siguientes valore únicos:
#             count
# gearbox
# manually   247254
# automatic   73984
# La columna NOTREPAIREDDAMAGE tiene las siguientes valore únicos:
#                     count
# notRepairedDamage
# no                 252854
# yes                 26604
# La columna KILOMETER tiene las siguientes valore únicos:
#             count
# kilometer
# 150000     213221
# 125000      35654
# 100000      14800
# 90000       11982
# 80000       10636
# La columna YEAROFREGISTRATION tiene las siguientes valore únicos:
#                     count
# yearOfRegistration
# 2005.00             21250
# 2006.00             19932
# 2000.00             19913
# 1999.00             19587
# 2003.00             19352
# La columna GAMA tiene las siguientes valore únicos:
#              count
# gama
# gama_alta   184729
# gama_baja    92175
# gama_media   50380
# unknown       3027
# gama_lujo     2499

# %% [markdown]
# # Columnas Nulas
# - vehicleType : Categórica
# - fuelType	: Categórica
# - gearbox : Categórica
# - notRepairedDamage	: Categórica

# %% [markdown]
# ### Vehicle Type

# %%
df["vehicleType"].unique()
# Out:
# array(['coupe', 'suv', 'small car', nan, 'convertible', 'bus', 'combi',
#        'other'], dtype=object)

# %% [markdown]
# Para la primera pondremos los nan en "other"

# %%
df["vehicleType"] = df["vehicleType"].fillna("other")
df["vehicleType"].unique()
# Out:
# array(['coupe', 'suv', 'small car', 'other', 'convertible', 'bus',
#        'combi'], dtype=object)

# %% [markdown]
# ### Fuel Type

# %%
df["fuelType"].unique()
# Out:
# array(['diesel', 'petrol', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electro'], dtype=object)

# %% [markdown]
# Para fuel pondremos los nan en "other"

# %%
df["fuelType"] = df["fuelType"].fillna("other")
df["fuelType"].unique()
# Out:
# array(['diesel', 'petrol', 'other', 'lpg', 'hybrid', 'cng', 'electro'],
#       dtype=object)

# %% [markdown]
# ### Gearbox

# %%
df["gearbox"].unique()
# Out:
# array(['manually', 'automatic', nan], dtype=object)

# %% [markdown]
# Lo pondremos como unknown

# %%
df["gearbox"] = df["gearbox"].fillna("unknown")
df["gearbox"].unique()
# Out:
# array(['manually', 'automatic', 'unknown'], dtype=object)

# %% [markdown]
# ### Not Repaired Damage

# %%
df["notRepairedDamage"].unique()
# Out:
# array(['yes', nan, 'no'], dtype=object)

# %% [markdown]
# Lo pondremos como unknown

# %%
df["notRepairedDamage"] = df["notRepairedDamage"].fillna("unknown")
df["notRepairedDamage"].unique()
# Out:
# array(['yes', 'unknown', 'no'], dtype=object)

# %% [markdown]
# ### Registered
#
# Vamos a crear una buena categoría, veamos años únicos

# %%
df["yearOfRegistration"].sort_values().unique()
# Out:
# array([1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0,
#        1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0,
#        1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0,
#        1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0,
#        1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0,
#        1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0,
#        1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0,
#        2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0,
#        2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, nan], dtype=object)

# %% [markdown]
# va de 1950 a 2019, vamos a realizar las siguientes categorías
#
# - 'Los 1950s',
# - 'Los 1960s',
# - 'Los 1970s',
# - 'Los 80',
# - 'Los 90',
# - 'Los 2000',
# - 'Los 2010'
#
# Como lo hare? la década la puedo sacar dividiendo por 10 absoluto (//) y multiplicando por 10

# %%
df["yearOfRegistration"] = df["yearOfRegistration"] //10 * 10
df["yearOfRegistration"].sort_values().unique()
# Out:
# array([1950.0, 1960.0, 1970.0, 1980.0, 1990.0, 2000.0, 2010.0, nan],
#       dtype=object)

# %% [markdown]
# Ahora paso a una lista esto, y genero un diccionario!

# %%
years = df["yearOfRegistration"].sort_values().unique()
lista_years = years.tolist()
lista_decadas = ["The 50's","The 60's","The 70's","The 80's","The 90's","The 2000","The 2010","unknown"]
dictio_decada = {}
for i, year in enumerate(lista_years):
    try:
        yeah = int(year)
    except: 
        yeah = np.nan
    dictio_decada[yeah] = lista_decadas[i]

dictio_decada
# Out:
# {1950: "The 50's",
#  1960: "The 60's",
#  1970: "The 70's",
#  1980: "The 80's",
#  1990: "The 90's",
#  2000: 'The 2000',
#  2010: 'The 2010',
#  nan: 'unknown'}

# %% [markdown]
# Y ahora reemplazamos

# %%
df["yearOfRegistration"] = df["yearOfRegistration"].map(dictio_decada)

# %%
df.sample(5)
# Out:
#          seller offerType vehicleType fuelType    gearbox notRepairedDamage  \
# 201248  private     offer       other   petrol  automatic                no
# 258621  private     offer   small car   petrol   manually                no
# 165487  private     offer       other   diesel  automatic               yes
# 174453  private     offer       combi   diesel   manually                no
# 314328  private     offer       other   petrol   manually                no
#
#        kilometer  powerCV  price yearOfRegistration       gama
# 201248     40000      NaN  28900           The 2010  gama_alta
# 258621     90000    52.00   2650           The 2000  gama_baja
# 165487    150000   178.00   1500           The 2000  gama_alta
# 174453    150000   134.00  10500           The 2000  gama_alta
# 314328    150000   129.00   2599           The 2000  gama_alta

# %%
df["yearOfRegistration"].unique()
# Out:
# array(['The 2010', 'The 2000', "The 90's", "The 80's", "The 60's",
#        "The 70's", 'unknown', "The 50's"], dtype=object)

# %% [markdown]
# Para ver si han cambiado los datos, vamos a guardar el df aquí

# %%
df_previo = df.copy()

# %% [markdown]
# Hagamos dos dataframes para ver que metodo de imputación funciona mejor

# %%
df1 = df.copy()
df2 = df.copy()

# %% [markdown]
# # Columnas numéricas
# ### Nulas
# - powerCV	: numérica
# - price	: numérica
# - yearOfRegistration : numérica
#
# Veamos información sobre los mismos:

# %%
df.describe().T
# Out:
#             count    mean     std    min     25%     50%     75%      max
# powerCV 297552.00  128.78   60.44  50.00   89.00  114.00  154.00  1146.00
# price   334882.00 6145.90 7422.14 500.00 1500.00 3500.00 7900.00 80000.00

# %%
df1.isnull().sum()
# Out:
# seller                    0
# offerType                 0
# vehicleType               0
# fuelType                  0
# gearbox                   0
# notRepairedDamage         0
# kilometer                 0
# powerCV               37330
# price                     0
# yearOfRegistration        0
# gama                      0
# dtype: int64

# %% [markdown]
# # Realizamos el Random Forest
# - A diferencia del Modelo 1 Vamos a intentar Rellenar los nulos con Random Forest

# %%
df_num = df1.select_dtypes(include=np.number)

# Random Forest
iterative_imputer = IterativeImputer(
    estimator=RandomForestRegressor(random_state=42),
    #max_iter=10,  # Número de iteraciones para ajustar los valores
    random_state=42
)

df_num_imputado = iterative_imputer.fit_transform(df_num)
df_num_sin_nulos = pd.DataFrame(df_num_imputado, columns=df_num.columns)
df_rf = df1.copy()
df_rf[df_num.columns] = df_num_sin_nulos
df_rf.isnull().sum()
# Out:
# seller                0
# offerType             0
# vehicleType           0
# fuelType              0
# gearbox               0
# notRepairedDamage     0
# kilometer             0
# powerCV               0
# price                 0
# yearOfRegistration    0
# gama                  0
# dtype: int64

# %% [markdown]
# Tarda 25 segundos

# %% [markdown]
# # Guardamos
#
# Veremos si mejora nuestros resultados

# %%
df_rf.to_csv("../../datos/06_Modelo6/02_autorenew_sin_nulos.csv")

# %% [markdown]
# # Gráficas Ahora!
# Cómo se nos queda?

# %% [markdown]
# ### Visualizar las numéricas con un histplot

# %%
df = pd.read_csv("../../datos/06_Modelo6/02_autorenew_sin_nulos.csv",index_col=0)
df["kilometer"] = df["kilometer"].astype(object)

# %%
numericas, categoricas = separarar_df(df)
plot_numericas(numericas)

# %% [markdown]
# ### Visualizar las categoricas con un countplot

# %%
plot_categoricas(categoricas,grafica_size=(20,20))

# %% [markdown]
# ### Visualizar los outliers con un boxplot

# %%
detectar_outliers(df)

# %% [markdown]
# # Matriz Correlación

# %%
matriz_correlacion(df)

# %% [markdown]
# ### Visualizar categoricas vs variable respuesta(barplot)

# %%
relacion_vr_categoricas(df,"price",grafica_size=(25,20))

# %% [markdown]
# ### Visualizar numericas vs variable respuesta con un (scatterplot)

# %%
relacion_vr_numericas(df,"price",grafica_size=(20,10))

# %%
df.isnull().sum()
# Out:
# seller                0
# offerType             0
# vehicleType           0
# fuelType              0
# gearbox               0
# notRepairedDamage     0
# kilometer             0
# powerCV               0
# price                 0
# yearOfRegistration    0
# gama                  0
# dtype: int64
